# %% [markdown]
# <b> MIS 382N: ADVANCED MACHINE LEARNING<b>
#
# Assignment 3
#
# Total points: 70
#
# Due: Monday, October 10 to be submitted via Canvas by 11:59 pm
#
# Your homework should be written in a python notebook. If you prefer, you can work in groups of two. **Please note that only one student per team needs to submit the assignment on Canvas but make sure to include both students' names and UT EIDs.**
#
# For any question that requires a handwritten solution, you may upload scanned images of your solution in the notebook or attach them to the assignment . You may write your solution using markdown as well.
#
# Please make sure your code runs and the graphs and figures are displayed in your notebook before submitting. (%matplotlib inline)

# %% [markdown]
# **This can be an individual assignment or group of 2. If you choose to do it as a group, please specify who you are working with (name and EID), then only one student should submit the homework. Put your name and eid here.**
#
# Name: Parthiv Borgohain
#
# EID: pb25347
#
# Name: Saurabh Arora
#
# EID: sa55445

# %% [markdown]
# #Question 1: Tensorflow Playground (20 pts)
#
# In this question, you will be playing with [Tensorflow Playground](https://playground.tensorflow.org).
#
#
# Select "Classification" as the Problem Type. Among the four datasets shown in DATA, please select the top left dataset.
#
# Use the following settings as the DEFAULT settings for all subquestions: Learning rate = 0.03, Activation = Tanh, Regularization = None, Ratio of training to test data = 50%, Noise = 0, Batch Size = 30, input as  𝑋1  with  𝑋2 , One hidden layer with 4 neurons.
#
# a) (4 pts) Use the DEFAULT setting and run two experiments - one using Tanh as the activation function and one using the Linear activation function. Report the train, test losses for both at the end of 1000 epochs. What qualitative difference do you observe in the decision boundaries obtained? What do you think is the reason for this?
#
# We will now study the effect of certain variations in the network structure or training process, keeping all other aspects the same as in the DEFAULT setting specified above, with Tanh as the activation.
#
# b) (4 pts) Effect of number of hidden units: Keep other settings the same as in DEFAULT, report the training loss and test loss at the end of 1000 epochs using 2 neurons and 8 neurons in the hidden layer. What do you observe in terms of the decision boundary obtained as the number of neurons increases? What do you think is the reason for this?
#
# c) (4 pts) Effect of Learning rate and number of epochs: Keep other settings the same as in DEFAULT. For learning rate 10, 1, 0.1, 0.01 and 0.0001, report the train, test losses at the end of 100 epochs, 500 epochs and 1000 epochs respectively. What do you observe from the change of loss vs learning rate, and the change of loss vs epoch numbers? Also report your observations on the training and test loss curve (observe if you see noise for certain learning rates and reason why this is happening).
#
# d) (4 pts) Effect of the number of layers: Change your activation to ReLU and use a single hidden layer with 4 neurons and then add another hidden layer with 3 neurons and train both your models for 1000 epochs. Comments on your final models and decision boundaries and observe your training and test loss curves as well.
#
# e) (4 pts) Use the DEFAULT setting. Play around with any hyperparameters, network architectures or input features (such as  sin(𝑋1),𝑋21  etc.), and report the best train and test loss you obtain (test loss should be no greater than 0.06). Attach the screenshot showing your full network, output and the parameters. Briefly justify your results, and comment on what helps/what doesn't help with lowering the loss, etc.

# %% [markdown]
# #### a) (4 pts) Use the DEFAULT setting and run two experiments - one using Tanh as the activation function and one using the Linear activation function. Report the train, test losses for both at the end of 1000 epochs. What qualitative difference do you observe in the decision boundaries obtained? What do you think is the reason for this?

# %% [markdown]
#  __Answer:__
#
# a)
#
#  __Tanh activation function results:__
# 1) Training loss = 0.003
#
# 2) Test loss = 0.008
#
# __Linear activation function results:__
# 1) Training loss = 0.499
#
# 2) Test loss = 0.498
#
# There is clearly a significant difference between the two error outputs as well as the decision boundaries for the two activation functions. The Linear activation function does not do a good job of finding the non-linear decision boundary of our dataset. However, the tanh activation function does a very good job of providing a decision boundary which correctly categorizes the non linearities the dataset.
#
# The main reason for the differences in decision boundaries is the nature of the two activation functions. The tanh activation function allows non-linearity to be modeled thereby resulting in an almost circular decision boundary. However, a model with a linear activation function can only provide a linear decision boundary and cannot provide the required circular decision boundary.

# %% [markdown]
# #### b) (4 pts) Effect of number of hidden units: Keep other settings the same as in DEFAULT, report the training loss and test loss at the end of 1000 epochs using 2 neurons and 8 neurons in the hidden layer. What do you observe in terms of the decision boundary obtained as the number of neurons increases? What do you think is the reason for this?

# %% [markdown]
# __Answer:__
#
# b)
#
# __Tanh activation function (2 neurons) results:__
# 1) Training loss = 0.176
#
# 2) Test loss = 0.235
#
#
# __Tanh activation function (8 neurons) results:__
# 1) Training loss = 0.002
#
# 2) Test loss = 0.003
#
# Clearly the neural network with 8 neurons in the hidden layer does a bettter job at classifying the data points. Increasing the no. of neurons in the hidden layer increases the complexity of the neural network. The decision boundary obtained for the network with 8 hidden neurons is nearly circular. But the model with 2 hidden neurons creates a decision boundary that is similar to a rectangle and the errors are high. This is because the model is not complex enough to model the required circular decision boundary.

# %% [markdown]
# #### c) (4 pts) Effect of Learning rate and number of epochs: Keep other settings the same as in DEFAULT. For learning rate 10, 1, 0.1, 0.01 and 0.0001, report the train, test losses at the end of 100 epochs, 500 epochs and 1000 epochs respectively. What do you observe from the change of loss vs learning rate, and the change of loss vs epoch numbers? Also report your observations on the training and test loss curve (observe if you see noise for certain learning rates and reason why this is happening).

# %% [markdown]
# __Answer:__
#
# c)
#
#
#   **Training Errors**
#
# | Learning Rate/Epoch |  100  | 500 | 1000 |
# |------|------|------|------|
# |   10  | 0.696|0.664 | 0.664|
# |   1  | 0.013|0.010 |0.000 |
# |   0.1  | 0.033|0.007 |0.004 |
# |   0.01 | 0.375|0.071 |0.028 |
# |   0.0001  | 0.526|0.510 |0.495 |
#
#  **Test Errors**
#
# | Learning Rate/Epoch |  100  | 500 | 1000 |
# |------|------|------|------|
# |   10  | 0.728|0.745 | 0.745|
# |   1  | 0.075|0.018 |0.064 |
# |   0.1  | 0.041|0.014 |0.010 |
# |   0.01 | 0.378|0.077 |0.036 |
# |   0.0001  | 0.508|0.496 |0.486 |
#
# So, clearly the error rate is pretty high for a high learning rate (10 in our case). High learning rates causes a lot of oscillations which prevents the weights from reaching their optimal values. With the decrease in Learning Rate, our error rates begin to decrease rapidly. However, making the learning rate very small once again increases the error rates. This is because the very low learning rates do not allow the weights to converge to an optimal solution.
#
# Also, when the no. of epochs is low, the error rate is pretty high. Models with more no. of epochs increases the complexity of the neural net as it increases the amount of training done. So, a model with 1000 epochs is more complex than a model with 100 or 500 epochs. From the tables above, we can infer that the error rates reduce as the no. of epochs increase for a particular neural net. However, if the learning rate is too high, the error rate may not necessarily reduce with an increase in the no. of epochs.
#
# We see that for neural nets with high learning rates (10 & 1), there's noise in the training & test loss curves. This is caused due to the big steps taken in gradient descent which cause a lot of oscillations in the values of the weights. The end result is that we see loss curves with a noise.

# %% [markdown]
# #### d) (4 pts) Effect of the number of layers: Change your activation to ReLU and use a single hidden layer with 4 neurons and then add another hidden layer with 3 neurons and train both your models for 1000 epochs. Comments on your final models and decision boundaries and observe your training and test loss curves as well.

# %% [markdown]
# __Answer:__
#
# d)
#
# __Results with 1 hidden layer (4 neurons):__
#
# 1) Training loss = 0.002
#
# 2) Test loss = 0.007
#
# The convergence is at around 350 epochs
# We have a hexagonal decision boundary
#
#
# __Results with 2 hidden layers (4 neurons, 3 neurons):__
#
# 1) Training loss = 0.000
#
# 2) Test loss = 0.001
#
# This has a much faster convergence.
# We have an irregular hexagonal decision boundary.
#
# With the addition of another hidden layer, we observe a major drop in the test and training losses. This can be attributed to the increase in flexibility of the model to capture a more complex function.
#
# We also understand that while adding additional hidden layers can help in capturing complexity, it can also go beyond a point of generalisability to overfit the training data and give higher test losses in cases where the model is more complex than the complexity requirement of the problem at hand.
#
# For the nueral with 2 hidden layers, the train and test learning curves started out with very little variance suggesting a very fast convergence. The end results after 1000 epochs is an almost perfect classification model with a nearly circular decision boundary and almost 0 test error.
#
# In our case with clear decision boundary, with just 1 layer, we dont really need another layer

# %% [markdown]
# #### e) (4 pts) Use the DEFAULT setting. Play around with any hyperparameters, network architectures or input features (such as sin(𝑋1),𝑋21 etc.), and report the best train and test loss you obtain (test loss should be no greater than 0.06). Attach the screenshot showing your full network, output and the parameters. Briefly justify your results, and comment on what helps/what doesn't help with lowering the loss, etc.

# %% [markdown]
# ![image1.png](attachment:image1.png)
#
# We were able to obtain both a training and test error of 0.000 using the settings shown in the screenshot. As the decision boundary must be ciruclar, we thought it would be better to include the squared forms x1 and x2. And indeed the decision boundary obtained was nearly a perfect circle. The activation function used was ReLU and the learning rate is 0.1. We decided not to take extremely high or low learning rate values. We achieved near loss after around 360 epochs.
#
# We found that $sin(X_1)$ & $sin(X_2)$ features are of almost no use at all in reducing error significantly even if more neurons & layers are added to the network. The error rates remain very high even with a very complex neural network. Even after 1000 epochs, the training and test error rates remained very high at 0.473 and 0.520 respectively.

# %% [markdown]
# # Question 2 : t-SNE (7 pts)
#
# Read this [article](https://erdem.pl/2020/04/t-sne-clearly-explained) on t-SNE, a dimensionality reduction technique for visualization and explain it in your own words in one or two paragraphs.

# %% [markdown]
# #### Answer:
#
# t-SNE is a **non-linear dimensionality reduction** technique. This algorithm allows us to separate data that cannot be separated by any straight line. In the first stage, the euclidean distances of every pair of points is calculated. Then, these distances are transformed into conditional probabilities that represent the similarity between every two points. The conditional probability ($p_{j|i}$) of point $x_{i}$ being next to point $x_{j}$ is calculated by assuming a Gaussian centered at $x_{i}$ with a standard deviation of $\sigma_{i}$. $\sigma_{i}$ is computed on the basis of the **Perplexity** parameter which can be interpreted as the no. of effective neighbours for each point. To calculate the conditional probability, we also divide the gaussian probability by the sum of all the probabilities of all the other points placed at the Gaussian centered at $x_{i}$ so that we can deal with clusters of different densities.
#
# From the conditional distributions created, we calculate the joint probability distribution for $p_{ij}$ as the mean of $p_{i|j}$ and $p_{j|i}$.
#
# In the next stage, we create a dataset of points in a low-dimensional space and calculate a joint probability distribution for them as well. To do this, we build a random dataset of points with the same number of points as we had in the original dataset, and K features, where K is our target dimension. For this set of points, we will calculate their joint probability distribution by using the t-distribution and not the Gaussian distribution.
#
# In the final stage, the **Kullback-Leiber divergence** is utilized to make the joint probability distribution of the data points in the low dimension as similar as possible to the one from the original dataset. If this transformation succeeds, we get a good dimension reduction of the original input data.

# %% [markdown]
# # Question 3: PCA (8 pts)
#
# Explain the principle of Principal Component Analysis algorithm and in what sense is the selection of the eigenvectors to represent the data is an optimal choice.  How do you reconstruct (a noisy version of) the original data from the eigenvectors and the loadings?

# %% [markdown]
# #### Answer:
#
#
# PCA aims to create a lower-dimensional representation that best represents the variance of the whole dataset. It uses Singular Value Decomposition to project data points to a lower dimension by trying to find a linear combination of inputs (called Principal Components) such that they capture most of the variance (information) present in the dataset. It is a dimensionality reduction technique.
#
# Eigenvalue decomposition of the Covariance Matrix gives both eigen values and eigenvectors. Hence, finding the eigenvalues and eigenvectors of the covariance matrix is the same as fitting the straight, principal component lines to data. As the eigenvectors trace the principal lines of force, and the axes of greatest variance and covariance illustrate where the data is most susceptible to change. By ranking the eigenvectors in order of their eigenvalues, highest to lowest, we get the principal components in order of significance.
#
# In order to reconstruct (a noisy version of) the original data from the eigenvectors and the scores, we can use:
#
# $$PCA\,Reconstruction= PC\,Scores⋅Eigenvectors^⊤ + Mean$$
#
# Where $PC\,Scores =  XV$
#
# and **X** is the centered Data Matrix (obtained after subtracting the mean vector **$\mu$** from each row) and **V** is the matrix of some k eigenvectors (PCs) that we want to use (usually the k eigenvectors with the k largest eigenvalues). The reconstruction obtained is a noisy reconstruction of the original input data.

# %% [markdown]
# # Question 4: Outlier detection using PyOD (20 pts)
#
# Outlier detection, or anomaly detection is usually an unsupervised learning task where the objective is to identify suspicious observations in data. It has been widely used in military surveillance for enemy activities to prevent attacks, intrusion detection in cyber security, fraud detection for credit cards, etc.
#
# PyOD is a comprehensive and scalable Python library for detecting outlying objects in multivariate data. PyOD includes more than 30 detection algorithms and provides unified APIs which makes it quite handy to use. In this question, you will play with PyOD, explore three different outlier detection algorithms and compare their performances. First let's install PyOD.
#
# ```
# # install pyod using pip first
# !pip install pyod
# ```
#
# You can load the data stored in 'Q3_train_dataset.csv' and 'Q3_test_dataset.csv' using the following codes.
#
# ```
# import pandas as pd
# # Load data code goes here
# train_df = pd.read_csv('Q3_train_dataset.csv')
# test_df = pd.read_csv('Q3_test_dataset.csv')
#
# X_train = train_df[['X_train_0', 'X_train_1', 'X_train_2', 'X_train_3', 'X_train_4']].to_numpy()
# y_train = train_df[['y_train']].to_numpy()
# X_test = test_df[['X_test_0', 'X_test_1', 'X_test_2', 'X_test_3', 'X_test_4']].to_numpy()
# y_test = test_df[['y_test']].to_numpy()
# ```
#
#  `X_train` and `X_test` contain the features, with the dimension of 5. `y_train` and `y_test` store the outlier labels, 0 means normal data, 1 means outlier data.
#
# a) **(5 pts)** **Fit `X_train` to a outlier detection model k Nearest Neighbors (kNN) using PyOD**, this [page](https://pyod.readthedocs.io/en/latest/pyod.models.html#module-pyod.models.mcd) will provide some functions you may need.
#
# ```
# from pyod.models.knn import KNN
# clf = KNN() # initialize KNN class using the default parameters
#
# # YOUR CODE SHOULD COME HERE, FIT THE MODEL USING X_TRAIN
# ```
# **Use the fitted model to predict the outlier labels of `X_test`. Compute the raw outlier scores on `X_test` using `decision_function()`.**
#
# **Run PyOD's `evaluate_print()` function using the test set ground truth outlier labels and the raw outlier scores predicted by the model, to compute the ROC and Precision@n results .**
#
# ```
# from pyod.utils.data import evaluate_print
# ```
#
# b) **(5 pts)** `X_train` and `X_test` are 5-dimension features, which makes it impossible to visualize them in Euclidean plane. But we can use Principal Component Analysis (PCA) to reduce the dimensions of `X_train` and `X_test` to 2, and then plot them. You may want to use `fit_and_transform()` function.
#
#
# ```
# from sklearn.decomposition import PCA
#
# pca = PCA(n_components=2)
#
# # Fit pca to X_train and X_test and transform
# train_principalComponents = # IMPLEMENT
# test_principalComponents = # IMPLEMENT
# ```
#
# After reducing the dimension to 2, now you can visualize the outliers using PyOD's `visualize()` function. Please plot the visualization. You may find [this](https://pyod.readthedocs.io/en/latest/pyod.utils.html#module-pyod.utils.example) useful on how to use `visualize()` .
#
# ```
# from pyod.utils.example import visualize
# ```
#
# Now you should be able to observe the ground truth outliers and the outliers predicted by the model.
#
#
# c) **(10 pts)** Apply the same process as in (a) and (b) to the following two models, and visualize the outlier results. Please compare the performance of the two models in terms of their ROC, Precision@n, and what you observe from the two visualizations.
#
# *   [Isolation-Based model - Isolation-based anomaly detection using Nearest-Neighbor Ensembles (INNE)](https://pyod.readthedocs.io/en/latest/pyod.models.html#module-pyod.models.inne)
#
# ```
# from pyod.models.inne import INNE
# ```
#
# # Answer:

# %%
# Only use this code block if you are using Google Colab.
# If you are using Jupyter Notebook, please ignore this code block. You can directly upload the file to your Jupyter Notebook file systems.
from google.colab import files

## It will prompt you to select a local file. Click on “Choose Files” then select and upload the file. 
## Wait for the file to be 100% uploaded. You should see the name of the file once Colab has uploaded it.
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c270fb62-09db-4bbd-ba75-661aea461750" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c270fb62-09db-4bbd-ba75-661aea461750">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# install pyod using pip first
# !pip install pyod
# Out:
# ...
#      -------------------------------------- 137.2/137.2 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pyod: filename=pyod-1.0.5-py3-none-any.whl size=170239 sha256=ff150a35b679409f6e2146365e8914af8d946106c58a577bcb8e25cb6e994331
#   Stored in directory: c:\users\sauar\appdata\local\pip\cache\wheels\1a\e6\6a\75d8ee3fd5ad45e84f2d45e98e2212e419dc7a6edfad950516
# Successfully built pyod
# ...

# %%
import pandas as pd
# Load data code goes here
train_df = pd.read_csv('Q3_train_dataset.csv')
test_df = pd.read_csv('Q3_test_dataset.csv')

X_train = train_df[['X_train_0', 'X_train_1', 'X_train_2', 'X_train_3', 'X_train_4']].to_numpy()
y_train = train_df[['y_train']].to_numpy()
X_test = test_df[['X_test_0', 'X_test_1', 'X_test_2', 'X_test_3', 'X_test_4']].to_numpy()
y_test = test_df[['y_test']].to_numpy()

# %%
# (a)
from pyod.models.knn import KNN
clf = KNN() # initialize KNN class using the default parameters

# fit the model using X_train
clf.fit(X_train)
y_train_pred = clf.labels_  
y_train_scores = clf.decision_scores_
y_test_pred = clf.predict(X_test)  
y_test_scores = clf.decision_function(X_test)

# YOUR CODE SHOULD COME HERE

# %%
from pyod.utils.data import evaluate_print
# predict the outlier labels of X_test using the trained model, compute the raw outlier scores on X_test using decision_function()
# then use evaluate_print() to print out the evaluation results
evaluate_print(clf,y_test,y_test_scores)
# YOUR CODE SHOULD COME HERE
# Out:
# KNN(algorithm='auto', contamination=0.1, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#   radius=1.0) ROC:0.9044, precision @ rank n:0.5

# %%
# (b)
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
pca = PCA(n_components=2)

# Fit pca to X_train and X_test and transform 

train_principalComponents = pca.fit_transform(X_train)# YOUR CODE SHOULD COME HERE
test_principalComponents = pca.fit_transform(X_test)# YOUR CODE SHOULD COME HERE

sc = StandardScaler()
# Fit_Transform_train = sc.fit_transform(train_principalComponents)
# Fit_Transform_test = sc.fit_transform(test_principalComponents)
from pyod.utils.example import visualize
# Visualize the ground truth outliers and predicted outliers using visualize()

visualize(clf, train_principalComponents, y_train, test_principalComponents, y_test, y_train_pred, y_test_pred, show_figure=True, save_figure=False)
# YOUR CODE SHOULD COME HERE
# Out:
# C:\Users\parth\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\parth\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# (c)
from pyod.models.inne import INNE

clf1 = INNE(random_state=1)
clf1.fit(X_train)
y_train_pred = clf1.labels_  
y_train_scores = clf1.decision_scores_
y_test_pred = clf1.predict(X_test)  
y_test_scores = clf1.decision_function(X_test)
evaluate_print(clf1,y_test,y_test_scores)

visualize(clf1, train_principalComponents, y_train, test_principalComponents, y_test, y_train_pred, y_test_pred, show_figure=True, save_figure=False)

# YOUR CODE SHOULD COME HERE
# Out:
# INNE(contamination=0.1, max_samples='auto', n_estimators=200, random_state=1) ROC:0.8533, precision @ rank n:0.5
# C:\Users\parth\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\parth\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # Solutions:
#
# The ROC scores of the two models are different. The ROC score of kNN is higher and its value is 0.9044. On the other hand, INNE has a lower ROC score of 0.8533. A better ROC score implies that the model is better at identifying the outliers accurately. Hence, for this dataset, kNN performs better than INNE at outlier detection.
#
# The value of precision @ rank n is the same for the kNN and INNE models. Hence in this regard, there is no difference between both the models.

# %% [markdown]
# # Question 5: Pre-processing and sampling (15 pts)
#
# The following dataset contains House prices describing the sales of individual residential property in Ames, Iowa data with explanatory variables describing almost every aspect of residential homes and dependent variable being SalePrice. Here, some cells of most columns in the dataset contain NaN values.

# %%
# Only use this code block if you are using Google Colab.
# If you are using Jupyter Notebook, please ignore this code block. You can directly upload the file to your Jupyter Notebook file systems.
from google.colab import files

## It will prompt you to select a local file. Click on “Choose Files” then select and upload the file. 
## Wait for the file to be 100% uploaded. You should see the name of the file once Colab has uploaded it.
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c8d069e0-5332-4874-9b0f-676b22f2ea13" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8d069e0-5332-4874-9b0f-676b22f2ea13">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd 
import numpy as np 
import scipy.stats as stats
import math
import matplotlib.pyplot as plt
np.random.seed(100)

data = pd.read_csv("sales_data.csv")
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Alley  OverallQual  OverallCond  \
# 0          60       RL         65.0     8450   NaN            7            5
# 1          20       RL         80.0     9600   NaN            6            8
# 2          60       RL         68.0    11250   NaN            7            5
# 3          70       RL         60.0     9550   NaN            7            5
# 4          60       RL         84.0    14260   NaN            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ... 3SsnPorch  ScreenPorch  PoolArea  \
# 0       2003          2003       196.0  ...         0            0         0
# 1       1976          1976         0.0  ...         0            0         0
# 2       2001          2002       162.0  ...         0            0         0
# 3       1915          1970         0.0  ...         0            0         0
# 4       2000          2000       350.0  ...         0            0         0
#
# ...

# %% [markdown]
# a)**(2 pts)**Print the number of NaN, NULL and empty values (combined sum) in each column.

# %%
data.isna().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Alley            1369
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# MasVnrArea          8
# ExterQual           0
# BsmtFinSF1          0
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageCars          0
# GarageArea          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ...

# %% [markdown]
# b)**(3 pts)**Create a copy of `data`, and name it `data_dm`, then create a new column in `data_dm` named `binned_garage_yr_built` and apply binning to the column `garage_yr_built`. Use `pandas.cut()` and modify its parameter list as below:
#
# ```
# bins=[1900, 1930, 1960, 1990, 2020]
# labels=['1900-1930', '1930-1960', '1960-1990', '1990-2020']
# include_lowest=True
# ```
# Next, perform one-hot encoding on this new column.

# %%
data_dm = data.copy()
data_dm.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Alley',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'ExterQual', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
data_dm=data.copy()
bins=[1900, 1930, 1960, 1990, 2020]
labels=['1900-1930', '1930-1960', '1960-1990', '1990-2020']
data_dm['binned_garage_yr_built']=pd.cut(data_dm['GarageYrBlt'], bins,labels=labels,include_lowest=True)

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder()
enc_df = pd.DataFrame(enc.fit_transform(data_dm[['binned_garage_yr_built']]).toarray())
data_dm = data_dm.join(enc_df)
data_dm=data_dm.rename({0:'1900-1930',1:'1930-1960',2:'1960-1990',3:'1990-2020'},axis='columns')
data_dm.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Alley  OverallQual  OverallCond  \
# 0          60       RL         65.0     8450   NaN            7            5
# 1          20       RL         80.0     9600   NaN            6            8
# 2          60       RL         68.0    11250   NaN            7            5
# 3          70       RL         60.0     9550   NaN            7            5
# 4          60       RL         84.0    14260   NaN            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ... MiscVal  MoSold  YrSold  \
# 0       2003          2003       196.0  ...       0       2    2008
# 1       1976          1976         0.0  ...       0       5    2007
# 2       2001          2002       162.0  ...       0       9    2008
# 3       1915          1970         0.0  ...       0       2    2006
# 4       2000          2000       350.0  ...       0      12    2008
#
#    SalePrice  binned_garage_yr_built 1900-1930 1930-1960 1960-1990  1990-2020  \
# ...

# %%
data_dm = data_dm.rename({4:'extra'},axis = 'columns')

# %%
data_dm[data_dm['extra'] == 1] #A new column has been created for NaN values of garage_yr_built
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Alley  OverallQual  \
# 39            90       RL         65.0     6040   NaN            4
# 48           190       RM         33.0     4456   NaN            4
# 78            90       RL         72.0    10778   NaN            4
# 88            50  C (all)        105.0     8470   NaN            3
# 89            20       RL         60.0     8070   NaN            4
# ...          ...      ...          ...      ...   ...          ...
# 1349          70       RM         50.0     5250  Pave            8
# 1407          20       RL          NaN     8780   NaN            5
# 1449         180       RM         21.0     1533   NaN            5
# 1450          90       RL         60.0     9000   NaN            5
# 1453          20       RL         90.0    17217   NaN            5
#
#       OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  ... MiscVal  MoSold  \
# 39              5       1955          1955         0.0  ...       0       6
# ...

# %% [markdown]
# c)**(3 pts)**Drop the columns which have more than 90%, 95% and 98% of missing values. List the columns which get dropped in each of the cases and observe the number of columns that get dropped in each of the cases as well.

# %%
#more than 90%
perc = 90
min_count =  int(((100-perc)/100)*data_dm.shape[0] + 1)
data_dm_90=data_dm.dropna(axis=1,thresh=min_count)
print("Dropped columns for 90% threshold: ",set(data_dm.columns)-set(data_dm_90.columns))
print('# of columns being dropped: ', len(set(data_dm.columns) - set(data_dm.dropna(axis = 1, thresh = (1-0.9) * data_dm.shape[0]).columns)))

perc = 95
min_count =  int(((100-perc)/100)*data_dm.shape[0] + 1)
data_dm_95 = data_dm.dropna(axis = 1,thresh = min_count)
print("\n\nDropped columns for 95% threshold: ",set(data_dm.columns)-set(data_dm_95.columns))
print('# of columns being dropped: ', len(set(data_dm.columns) - set(data_dm.dropna(axis = 1, thresh = (1-0.95) * data_dm.shape[0]).columns)))

perc = 98
min_count =  int(((100-perc)/100)*data_dm.shape[0] + 1)
data_dm_98 = data_dm.dropna(axis = 1,thresh = min_count)
print("\n\nDropped columns for 98% threshold: ",set(data_dm.columns)-set(data_dm_98.columns))
print('# of columns being dropped: ', len(set(data_dm.columns) - set(data_dm.dropna(axis = 1, thresh = (1-0.98) * data_dm.shape[0]).columns)))
# Out:
# Dropped columns for 90% threshold:  {'PoolQC', 'MiscFeature', 'Alley'}
# # of columns being dropped:  3
#
#
# Dropped columns for 95% threshold:  {'PoolQC', 'MiscFeature'}
# # of columns being dropped:  2
#
#
# Dropped columns for 98% threshold:  {'PoolQC'}
# # of columns being dropped:  1

# %% [markdown]
# d)**(2 pts)**Take a sample of 800 rows at random and compute its mean. Compare the result with the population mean

# %%
np.random.seed(6)
sample_ages = np.random.choice(a= data['SalePrice'], size=800)
#Sample mean
print("Sample Mean is:",sample_ages.mean())
#Population mean
print("population Mean is:",data['SalePrice'].mean())
print("Difference between Population Mean and Sample Mean is:",data['SalePrice'].mean()-sample_ages.mean())
# Out:
# Sample Mean is: 178292.63125
# population Mean is: 180921.19589041095
# Difference between Population Mean and Sample Mean is: 2628.564640410943

# %% [markdown]
# e) i)**(2pts)** Calculate 95% confidence intervals for SalePrice with a sample size of 100.

# %%
import scipy
np.random.seed(10)
sample_size = 100
sample = np.random.choice(a= data_dm['SalePrice'],
                          size = sample_size)
sample_mean = sample.mean()

#Get the critical Z value

z_critical = scipy.stats.norm.ppf(1-.05/2) #two tailed

#Get population standard deviation
population_mean = data_dm['SalePrice'].mean()
pop_stdev = data_dm['SalePrice'].std()

#margin of error
margin_of_error = z_critical * (pop_stdev/math.sqrt(sample_size)) 

#confidence interval
confidence_interval = (sample_mean - margin_of_error,
                       sample_mean + margin_of_error)  

#Print confidence interval and true mean value
print("95% Confidence Interval for Sample Mean is: ",confidence_interval)
print("True Population Mean is: ",population_mean)
# Out:
# 95% Confidence Interval for Sample Mean is:  (166522.08555078227, 197662.97444921773)
# True Population Mean is:  180921.19589041095

# %% [markdown]
# ii)**(3pts)** Calculate 95 % confidence intervals for 100 different trials with a sample size of 500. Plot the confidence intervals and interpret how it captures the population mean.

# %%
np.random.seed(12)

#define the sample size
sample_size = 500

intervals = []
sample_means = []

for sample in range(100):
    sample = np.random.choice(a= data_dm['SalePrice'], size = sample_size)
    sample_mean = sample.mean()
    sample_means.append(sample_mean)
    #compute z critical value
    z_critical = scipy.stats.norm.ppf(1-.05/2)
    #compute population std dev        
    pop_stdev = data_dm["SalePrice"].std()
    
    margin_of_error = z_critical * (pop_stdev/math.sqrt(sample_size))
    confidence_interval = (sample_mean - margin_of_error,
                           sample_mean + margin_of_error)  
    
    intervals.append(confidence_interval)
    

plt.figure(figsize=(13, 9))

plt.errorbar(x=np.arange(0.1, 100, 1), 
             y=sample_means, 
             yerr=[(top-bot)/2 for top,bot in intervals],
             fmt='o')

plt.hlines(xmin=0, xmax=100,
           y=data['SalePrice'].mean(), 
           linewidth=2.0,
           color="red")
plt.title('Confidence Intervals for 100 Trials', fontsize = 20)
plt.show()

# %% [markdown]
# ### Solution:
#
# The 95% confidence intervals tell us that if  we repeat the same experiment many times and draw many sample means (along with their confidence intervals), the confidence intervals created will contain the population mean about 95% of the time.In this plot, we are plotting 95% confidence intervals for 100 trials with sample size 500. From the plot, we can see that the population mean exists within approx 95% of these intervals.
#
# Thus, we can clearly observe that the 95% confidence intervals will capture the population mean about 95% of the time.
